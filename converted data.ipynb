# %% [markdown]
# # EDSA APPLE PRICES

# %% [markdown]
# # REGRESSION_AM6_DFST_PREDICT
# @ Melusi Zwane
# @ Itumeleng Mabaso
# @ Onkarabile Tshele
# @ lydia lehutjo
# @ Samuel Moloantoa

# %% [markdown]
# ## Objective
# In this predict we should do the following:
#
# - Be able to clean the given data
# - Be able to intercept the type of graph needed
# - Be able to create a code to correctly predict the given data

# %% [markdown]
# # Importing data and plotting

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc

# %% [markdown]
# we will load the data onto the notebook

# %% [markdown]
# Challenge Description
# Imagine you are in the Fresh Produce Industry. How much stock do you have on hand? Not too little that you run out of stock when customers want to buy more. And not too much that food waste occurs. How do you set your prices? Yields from farms fluctuate by season. Should your prices then also fluctuate by season?

# %% [markdown]
# With this context, EDSA is challenging you to construct a regression algorithm, capable of accurately predicting how much a kilogram of Golden Delicious Apples will cost, given certain parameters.

# %% [markdown]
# Providing an accurate and robust solution to this challenge has immense economic potential, with users of the system being able to accurately determine how much stock to have on hand and what price to set the Golden Delicious Apples to.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/onkarabiletshele/Regression_AM6_DSFT/main/df%20-%20train_set.csv')

# %%
# will show the first few data
df.head(20)
# Out:
#                  Province Container Size_Grade  Weight_Kg  \
# 0                    CAPE     EC120         1L       12.0
# 1                    CAPE     M4183         1L       18.3
# 2                 GAUTENG     AT200         1L       20.0
# 3               TRANSVAAL     BJ090         1L        9.0
# 4       WESTERN FREESTATE     PP100         1R       10.0
# 5               TRANSVAAL     AP010         2M        1.0
# 6                   NATAL     BI100         1M       10.0
# 7                    CAPE     JG110         2M       11.0
# 8               TRANSVAAL     LA020         1M        2.0
# 9                   NATAL     AD100         2X       10.0
# 10              TRANSVAAL     BN150         3L       15.0
# 11          KWAZULU NATAL     AE050         2L        5.0
# 12  IMPORTS - OUTSIDE RSA     BC180          M       18.0
# 13                  NATAL     BN150         2M       15.0
# 14                  NATAL     BD100         1M       10.0
# 15                   CAPE     EC120         1S       12.0
# 16            OTHER AREAS     PD050          1        5.0
# 17      WESTERN FREESTATE     PP100         1M       10.0
# 18              TRANSVAAL     BC180          L       18.0
# 19          NORTHERN CAPE     AG100         1M       10.0
#
#                Commodities        Date  Low_Price  High_Price  Sales_Total  \
# 0       APPLE GRANNY SMITH  2020-03-10      108.0       112.0       3236.0
# 1   APPLE GOLDEN DELICIOUS  2020-09-09      150.0       170.0      51710.0
# 2        AVOCADO PINKERTON  2020-05-05       70.0        80.0       4860.0
# 3       TOMATOES-LONG LIFE  2020-01-20       60.0        60.0        600.0
# 4    POTATO SIFRA (WASHED)  2020-07-14       40.0        45.0      41530.0
# 5       TOMATOES-LONG LIFE  2020-02-03        8.0        14.0      82576.0
# 6                    NOVAS  2020-07-09       20.0       110.0      14490.0
# 7   APPLE GOLDEN DELICIOUS  2020-04-14       50.0        50.0      16000.0
# 8                 SATSUMAS  2020-05-27       15.0        15.0         30.0
# 9          GARLIC IMPORTED  2020-07-01      300.0       300.0      14700.0
# 10                   LEMON  2020-03-09      120.0       120.0       8760.0
# 11       CUCUMBERS ENGLISH  2020-07-23       60.0        80.0       7210.0
# 12                  BANANA  2020-05-07      120.0       220.0     100750.0
# 13                   LEMON  2020-06-24       50.0        60.0        270.0
# 14          TOMATOES OTHER  2020-06-02       20.0        40.0       1640.0
# 15          APPLE BRAEBURN  2020-07-09       50.0        90.0      21796.0
# 16       GRAPE OTHER WHITE  2020-09-03      300.0       340.0      17860.0
# 17   POTATO SIFRA (WASHED)  2020-08-31       62.0        68.0     127270.0
# 18   BANANA FINGERS SINGLE  2020-06-18      100.0       100.0        900.0
# 19            ONIONS BROWN  2020-02-06       42.0        45.0       2580.0
#
#     Total_Qty_Sold  Total_Kg_Sold  Stock_On_Hand  avg_price_per_kg
# 0               29          348.0              0              9.30
# 1              332         6075.6            822              8.51
# 2               66         1320.0             50              3.68
# 3               10           90.0              0              6.67
# 4              927         9270.0            393              4.48
# 5             8064         8064.0            485             10.24
# 6              180         1800.0              0              8.05
# 7              320         3520.0              0              4.55
# 8                2            4.0           3230              7.50
# 9               49          490.0              0             30.00
# 10              73         1095.0            167              8.00
# 11             102          510.0              0             14.14
# 12             704        12672.0           1655              7.95
# 13               5           75.0             58              3.60
# 14              42          420.0              0              3.90
# 15             286         3432.0             33              6.35
# 16              55          275.0              0             64.95
# 17            1957        19570.0            442              6.50
# 18               9          162.0            100              5.56
# 19              58          580.0            132              4.45

# %%
df = pd.read_csv('https://raw.githubusercontent.com/onkarabiletshele/Regression_AM6_DSFT/main/df%20-%20test_set.csv')

# %%
df.head(20)
# Out:
#     Index              Province Container Size_Grade  Weight_Kg  \
# 0       1  W.CAPE-BERGRIVER ETC     EC120         1M       12.0
# 1       2  W.CAPE-BERGRIVER ETC     M4183         1X       18.3
# 2       3  W.CAPE-BERGRIVER ETC     EC120         1S       12.0
# 3       4  W.CAPE-BERGRIVER ETC     M4183         1M       18.3
# 4       5  W.CAPE-BERGRIVER ETC     M4183         1L       18.3
# 5       6                  CAPE     IA400         1S      400.0
# 6       7                  CAPE     JG110         2S       11.0
# 7       8                  CAPE     M4183         1M       18.3
# 8       9                  CAPE     M4183         1X       18.3
# 9      10  W.CAPE-BERGRIVER ETC     M4183         1X       18.3
# 10     11                  CAPE     JE090         2M        9.0
# 11     12  W.CAPE-BERGRIVER ETC     IA400         1S      400.0
# 12     13                  CAPE     M4183         1X       18.3
# 13     14                  CAPE     JE090         2U        9.0
# 14     15                 NATAL     JE090         2S        9.0
# 15     16  W.CAPE-BERGRIVER ETC     JE090         2M        9.0
# 16     17                  CAPE     M6125         1M       12.5
# 17     18                  CAPE     JE090         2U        9.0
# 18     19  W.CAPE-BERGRIVER ETC     M4183         1L       18.3
# 19     20                  CAPE     JE090         2M        9.0
#
#                Commodities        Date  Low_Price  High_Price  Sales_Total  \
# 0   APPLE GOLDEN DELICIOUS  2020-07-09      128.0       136.0       5008.0
# 1   APPLE GOLDEN DELICIOUS  2020-01-20      220.0       220.0       1760.0
# 2   APPLE GOLDEN DELICIOUS  2020-08-19      120.0       120.0        720.0
# 3   APPLE GOLDEN DELICIOUS  2020-05-06      160.0       160.0        160.0
# 4   APPLE GOLDEN DELICIOUS  2020-05-04      140.0       160.0      14140.0
# 5   APPLE GOLDEN DELICIOUS  2020-03-20     1500.0      2000.0       9300.0
# 6   APPLE GOLDEN DELICIOUS  2020-01-11       40.0        40.0        320.0
# 7   APPLE GOLDEN DELICIOUS  2020-07-29      112.0       160.0      17472.0
# 8   APPLE GOLDEN DELICIOUS  2020-08-03      120.0       180.0      18410.0
# 9   APPLE GOLDEN DELICIOUS  2020-05-29      170.0       170.0       2210.0
# 10  APPLE GOLDEN DELICIOUS  2020-05-29       40.0        60.0        855.0
# 11  APPLE GOLDEN DELICIOUS  2020-07-07     2400.0      2400.0       2400.0
# 12  APPLE GOLDEN DELICIOUS  2020-01-13      130.0       170.0       1290.0
# 13  APPLE GOLDEN DELICIOUS  2020-04-16       40.0        40.0         80.0
# 14  APPLE GOLDEN DELICIOUS  2020-07-21       40.0        50.0      11095.0
# 15  APPLE GOLDEN DELICIOUS  2020-04-01       55.0        55.0        330.0
# 16  APPLE GOLDEN DELICIOUS  2020-01-14      100.0       100.0        100.0
# 17  APPLE GOLDEN DELICIOUS  2020-04-22       40.0        50.0       2200.0
# 18  APPLE GOLDEN DELICIOUS  2019-12-23      180.0       260.0      50595.0
# 19  APPLE GOLDEN DELICIOUS  2020-03-05       50.0        60.0      18500.0
#
#     Total_Qty_Sold  Total_Kg_Sold  Stock_On_Hand
# 0               38          456.0              0
# 1                8          146.4              2
# 2                6           72.0             45
# 3                1           18.3              8
# 4              100         1830.0             19
# 5                5         2000.0            129
# 6                8           88.0             13
# 7              115         2104.5            516
# 8              120         2196.0            296
# 9               13          237.9              9
# 10              18          162.0            101
# 11               1          400.0             19
# 12               8          146.4            132
# 13               2           18.0             31
# 14             271         2439.0             76
# 15               6           54.0           1333
# 16               1           12.5             69
# 17              54          486.0            107
# 18             270         4941.0           2982
# 19             324         2916.0             60

# %%
df = pd.read_csv('https://raw.githubusercontent.com/onkarabiletshele/Regression_AM6_DSFT/main/sample_submission.csv')

# %%
df.head()
# Out:
#    Index  Price
# 0      1  13.94
# 1      2   1.30
