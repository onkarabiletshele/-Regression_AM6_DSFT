# %% [markdown]
# # EDSA APPLE PRICES(TRAIN SET)

# %% [markdown]
# REGRESSION_AM6_DFST_PREDICT¶
# - Melusi Zwane
# - Itumeleng Mabaso
# - Onkarabile Tshele
# - lydia lehutjo
# - Samuel Moloantoa

# %% [markdown]
# # Objective
#
# In this predict we should do the following:
#
# - Be able to clean the given data
# - Be able to intercept the type of graph needed
# - Be able to create a code to correctly predict the given data

# %% [markdown]
# # importing data and plotting

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## we will load the data onto the notebook

# %% [markdown]
# - Challenge Description Imagine you are in the Fresh Produce Industry. How much stock do you have on hand? Not too little that you run out of stock when customers want to buy more. And not too much that food waste occurs. How do you set your prices? Yields from farms fluctuate by season. Should your prices then also fluctuate by season?
#
# - With this context, EDSA is challenging you to construct a regression algorithm, capable of accurately predicting how much a kilogram of Golden Delicious Apples will cost, given certain parameters.
#
# - Providing an accurate and robust solution to this challenge has immense economic potential, with users of the system being able to accurately determine how much stock to have on hand and what price to set the Golden Delicious Apples to.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/onkarabiletshele/Regression_AM6_DSFT/e079a104929f71959d05bd2e35f00a6c9118ca25/Data/df-train_set.csv')

# %%
# we will show you a few data
df.head(30)
# Out:
#                     Province Container Size_Grade  Weight_Kg  \
# 0                       CAPE     EC120         1L       12.0
# 1                       CAPE     M4183         1L       18.3
# 2                    GAUTENG     AT200         1L       20.0
# 3                  TRANSVAAL     BJ090         1L        9.0
# 4          WESTERN FREESTATE     PP100         1R       10.0
# 5                  TRANSVAAL     AP010         2M        1.0
# 6                      NATAL     BI100         1M       10.0
# 7                       CAPE     JG110         2M       11.0
# 8                  TRANSVAAL     LA020         1M        2.0
# 9                      NATAL     AD100         2X       10.0
# 10                 TRANSVAAL     BN150         3L       15.0
# 11             KWAZULU NATAL     AE050         2L        5.0
# 12     IMPORTS - OUTSIDE RSA     BC180          M       18.0
# 13                     NATAL     BN150         2M       15.0
# ...

# %%
df.dtypes
# Out:
# Province             object
# Container            object
# Size_Grade           object
# Weight_Kg           float64
# Commodities          object
# Date                 object
# Low_Price           float64
# High_Price          float64
# Sales_Total         float64
# Total_Qty_Sold        int64
# Total_Kg_Sold       float64
# Stock_On_Hand         int64
# avg_price_per_kg    float64
# dtype: object

# %% [markdown]
# # Import Data

# %%
plt.figure(figsize = (20,10))
plt.bar(df['Size_Grade'], df['avg_price_per_kg'])

# Set x and y axis titles
# plt.ylabel('avg_price_per_kg')
# plt.xlabel('Size_Grade') # Note: '\n' creates a newline (try removing it and see what happens)  

# Set graph title
# plt.title('Size_Grade vs avg_price_per_kg')

# Show graph
plt.show()

# %%
plt.figure(figsize = (20,10))
plt.scatter(df['Weight_Kg'], df['avg_price_per_kg'])

# Set x and y axis titles
plt.ylabel('avg_price_per_kg')
plt.xlabel('Weight_Kg') # Note: '\n' creates a newline (try removing it and see what happens)  

# Set graph title
# plt.title('Size_Grade vs avg_price_per_kg')

# Show graph
plt.show()

# %%
sns.distplot(df['avg_price_per_kg'] , fit=norm);

# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(train['avg_price_per_kg'])

#Now plot the distribution
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('SalePrice distribution')
